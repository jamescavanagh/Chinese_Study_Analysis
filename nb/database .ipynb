# %%
# Creating the data Needed
# Objective 1 List of Vocabulary words
# Objective 2 
# Objectiev 3

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /home/jentlejames/.local/lib/python3.10/site-packages (4.3.2)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 1.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: dnspython
# Successfully installed dnspython-2.2.1

# %%
import pandas as  pd
import pymongo 
from bson.objectid import ObjectId

from pathlib import Path

# %% [markdown]
# ### Setting up Mongodb
#
# use docker image
#
#  Install docker rootless
#
# https://itnext.io/docker-running-in-rootless-mode-bdbcfc728b3a?gi=ae7bdacb5a5c

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
db = client['cedict']

# %%
cedict = db['cedict']

# %%
#A parser for the CC-Cedict. Convert the Chinese-English dictionary into a list of python dictionaries with "traditional","simplified", "pinyin", and "english" keys.

#Make sure that the cedict_ts.u8 file is in the same folder as this file, and that the name matches the file name on line 13.

#Before starting, open the CEDICT text file and delete the copyright information at the top. Otherwise the program will try to parse it and you will get an error message.

#Characters that are commonly used as surnames have two entries in CC-CEDICT. This program will remove the surname entry if there is another entry for the character. If you want to include the surnames, simply delete lines 59 and 60.

#This code was written by Franki Allegra in February 2020.

#open CEDICT file



with open('../data/cedict_ts.u8') as file:
    text = file.read()
    lines = text.split('\n')
    dict_lines = list(lines)

#define functions

    def parse_line(line):
        parsed = {}
        if line == '':
            dict_lines.remove(line)
            return 0
        line = line.rstrip('/')
        line = line.split('/')
        if len(line) <= 1:
            return 0
        english = line[1]
        char_and_pinyin = line[0].split('[')
        characters = char_and_pinyin[0]
        characters = characters.split()
        traditional = characters[0]
        simplified = characters[1]
        pinyin = char_and_pinyin[1]
        pinyin = pinyin.rstrip()
        pinyin = pinyin.rstrip("]")
        parsed['traditional'] = traditional
        parsed['simplified'] = simplified
        parsed['pinyin'] = pinyin
        parsed['english'] = english
        list_of_dicts.append(parsed)

    def remove_surnames():
        for x in range(len(list_of_dicts)-1, -1, -1):
            if "surname " in list_of_dicts[x]['english']:
                if list_of_dicts[x]['traditional'] == list_of_dicts[x+1]['traditional']:
                    list_of_dicts.pop(x)
            
    def main():

        #make each line into a dictionary
        print("Parsing dictionary . . .")
        for line in dict_lines:
                parse_line(line)
        
        #remove entries for surnames from the data (optional):

        print("Removing Surnames . . .")
        remove_surnames()

        return list_of_dicts


        #If you want to save to a database as JSON objects, create a class Word in the Models file of your Django project:

        # print("Saving to database (this may take a few minutes) . . .")
        # for one_dict in list_of_dicts:
        #     new_word = Word(traditional = one_dict["traditional"], simplified = one_dict["simplified"], english = one_dict["english"], pinyin = one_dict["pinyin"], hsk = one_dict["hsk"])
        #     new_word.save()
        print('Done!')

list_of_dicts = []
parsed_dict = main()#A parser for the CC-Cedict. Convert the Chinese-English dictionary into a list of python dictionaries with "traditional","simplified", "pinyin", and "english" keys.

#Make sure that the cedict_ts.u8 file is in the same folder as this file, and that the name matches the file name on line 13.

#Before starting, open the CEDICT text file and delete the copyright information at the top. Otherwise the program will try to parse it and you will get an error message.

#Characters that are commonly used as surnames have two entries in CC-CEDICT. This program will remove the surname entry if there is another entry for the character. If you want to include the surnames, simply delete lines 59 and 60.

#This code was written by Franki Allegra in February 2020.

#open CEDICT file

with open('../data/cedict_ts.u8') as file:
    text = file.read()
    lines = text.split('\n')
    dict_lines = list(lines)

#define functions

    def parse_line(line):
        parsed = {}
        if line == '':
            dict_lines.remove(line)
            return 0
        line = line.rstrip('/')
        line = line.split('/')
        if len(line) <= 1:
            return 0
        english = line[1]
        char_and_pinyin = line[0].split('[')
        characters = char_and_pinyin[0]
        characters = characters.split()
        traditional = characters[0]
        simplified = characters[1]
        pinyin = char_and_pinyin[1]
        pinyin = pinyin.rstrip()
        pinyin = pinyin.rstrip("]")
        parsed['traditional'] = traditional
        parsed['simplified'] = simplified
        parsed['pinyin'] = pinyin
        parsed['english'] = english
        list_of_dicts.append(parsed)

    def remove_surnames():
        for x in range(len(list_of_dicts)-1, -1, -1):
            if "surname " in list_of_dicts[x]['english']:
                if list_of_dicts[x]['traditional'] == list_of_dicts[x+1]['traditional']:
                    list_of_dicts.pop(x)
            
    def main():

        #make each line into a dictionary
        print("Parsing dictionary . . .")
        for line in dict_lines:
                parse_line(line)
        
        #remove entries for surnames from the data (optional):

        print("Removing Surnames . . .")
        remove_surnames()

        return list_of_dicts


        #If you want to save to a database as JSON objects, create a class Word in the Models file of your Django project:

        # print("Saving to database (this may take a few minutes) . . .")
        # for one_dict in list_of_dicts:
        #     new_word = Word(traditional = one_dict["traditional"], simplified = one_dict["simplified"], english = one_dict["english"], pinyin = one_dict["pinyin"], hsk = one_dict["hsk"])
        #     new_word.save()
        print('Done!')

list_of_dicts = []
parsed_dict = main()
# Out:
# Parsing dictionary . . .
# Removing Surnames . . .
# Parsing dictionary . . .
# Removing Surnames . . .

# %%
parsed_dict
# Out:
# [{'traditional': '2019冠狀病毒病',
#   'simplified': '2019冠状病毒病',
#   'pinyin': 'er4 ling2 yi1 jiu3 guan1 zhuang4 bing4 du2 bing4',
#   'english': 'COVID-19, the coronavirus disease identified in 2019',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69d9')},
#  {'traditional': '21三體綜合症',
#   'simplified': '21三体综合症',
#   'pinyin': 'er4 shi2 yi1 san1 ti3 zong1 he2 zheng4',
#   'english': 'trisomy',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69da')},
#  {'traditional': '3C',
#   'simplified': '3C',
#   'pinyin': 'san1 C',
#   'english': 'abbr. for computers, communications, and consumer electronics',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69db')},
#  {'traditional': '3P',
#   'simplified': '3P',
#   'pinyin': 'san1 P',
#   'english': '(slang) threesome',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69dc')},
#  {'traditional': '3Q',
#   'simplified': '3Q',
#   'pinyin': 'san1 Q',
#   'english': '(Internet slang) thank you (loanword)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69dd')},
#  {'traditional': '421',
#   'simplified': '421',
#   'pinyin': 'si4 er4 yi1',
#   'english': 'four grandparents, two parents and an only child',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69de')},
#  {'traditional': '502膠',
#   'simplified': '502胶',
#   'pinyin': 'wu3 ling2 er4 jiao1',
#   'english': 'cyanoacrylate glue',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69df')},
#  {'traditional': '88',
#   'simplified': '88',
#   'pinyin': 'ba1 ba1',
#   'english': '(Internet slang) bye-bye (alternative for 拜拜[bai2 bai2])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e0')},
#  {'traditional': '996',
#   'simplified': '996',
#   'pinyin': 'jiu3 jiu3 liu4',
#   'english': '9am-9pm, six days a week (work schedule)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e1')},
#  {'traditional': 'A',
#   'simplified': 'A',
#   'pinyin': 'A',
#   'english': '(slang) (Tw) to steal',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e2')},
#  {'traditional': 'AA制',
#   'simplified': 'AA制',
#   'pinyin': 'A A zhi4',
#   'english': 'to split the bill',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e3')},
#  {'traditional': 'AB制',
#   'simplified': 'AB制',
#   'pinyin': 'A B zhi4',
#   'english': 'to split the bill (where the male counterpart foots the larger portion of the sum)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e4')},
#  {'traditional': 'ACG',
#   'simplified': 'ACG',
#   'pinyin': 'A C G',
#   'english': 'acronym for "anime, comics and games"',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e5')},
#  {'traditional': 'A咖',
#   'simplified': 'A咖',
#   'pinyin': 'A ka1',
#   'english': 'class "A"',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e6')},
#  {'traditional': 'A圈兒',
#   'simplified': 'A圈儿',
#   'pinyin': 'A quan1 r5',
#   'english': 'at symbol, @',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e7')},
#  {'traditional': 'A片',
#   'simplified': 'A片',
#   'pinyin': 'A pian4',
#   'english': 'adult movie',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e8')},
#  {'traditional': 'A菜',
#   'simplified': 'A菜',
#   'pinyin': 'A cai4',
#   'english': '(Tw) A-choy, or Taiwanese lettuce (Lactuca sativa var. sativa) (from Taiwanese 萵仔菜, Tai-lo pr. [ue-á-tshài] or [e-á-tshài])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69e9')},
#  {'traditional': 'A貨',
#   'simplified': 'A货',
#   'pinyin': 'A huo4',
#   'english': 'good-quality fake',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69ea')},
#  {'traditional': 'B',
#   'simplified': 'B',
#   'pinyin': 'bi1',
#   'english': 'euphemistic variant of 屄[bi1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69eb')},
#  {'traditional': 'BM',
#   'simplified': 'BM',
#   'pinyin': 'B M',
#   'english': 'Brandy Melville, fashion brand known for clothes targeted at very slim young women',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69ec')},
#  {'traditional': 'BP機',
#   'simplified': 'BP机',
#   'pinyin': 'B P ji1',
#   'english': 'beeper (loanword)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69ed')},
#  {'traditional': 'B型超聲',
#   'simplified': 'B型超声',
#   'pinyin': 'B xing2 chao1 sheng1',
#   'english': 'type-B ultrasound',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69ee')},
#  {'traditional': 'B格',
#   'simplified': 'B格',
#   'pinyin': 'bi1 ge2',
#   'english': 'variant of 逼格[bi1 ge2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69ef')},
#  {'traditional': 'B站',
#   'simplified': 'B站',
#   'pinyin': 'B zhan4',
#   'english': '(coll.) Bilibili, Chinese video-sharing website featuring scrolled user comments 彈幕|弹幕[dan4 mu4] overlaid on the videos',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f0')},
#  {'traditional': 'B超',
#   'simplified': 'B超',
#   'pinyin': 'B chao1',
#   'english': 'B-mode ultrasonography',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f1')},
#  {'traditional': 'CJB',
#   'simplified': 'CJB',
#   'pinyin': 'C J B',
#   'english': "(Internet slang) doesn't live up to the hype",
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f2')},
#  {'traditional': 'CP',
#   'simplified': 'CP',
#   'pinyin': 'C P',
#   'english': 'an imagined romantic relationship between two characters in fiction (or in real life) that one wishes for or fantasizes about (abbr. of "coupling")',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f3')},
#  {'traditional': 'CP值',
#   'simplified': 'CP值',
#   'pinyin': 'C P zhi2',
#   'english': '(Tw) value for money',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f4')},
#  {'traditional': 'C位',
#   'simplified': 'C位',
#   'pinyin': 'C wei4',
#   'english': '(neologism, c. 2015) (coll.) most prominent position (e.g. in a group photo of entertainers) (loanword from "carry" or "center" or "core")',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f5')},
#  {'traditional': 'C盤',
#   'simplified': 'C盘',
#   'pinyin': 'C pan2',
#   'english': 'C drive or default startup drive (computing)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f6')},
#  {'traditional': 'C羅',
#   'simplified': 'C罗',
#   'pinyin': 'C Luo2',
#   'english': 'nickname of Portuguese soccer player Cristiano Ronaldo',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f7')},
#  {'traditional': 'DNA鑒定',
#   'simplified': 'DNA鉴定',
#   'pinyin': 'D N A jian4 ding4',
#   'english': 'DNA test',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f8')},
#  {'traditional': 'E仔',
#   'simplified': 'E仔',
#   'pinyin': 'E zai3',
#   'english': 'MDMA (C11H15NO2)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69f9')},
#  {'traditional': 'G友',
#   'simplified': 'G友',
#   'pinyin': 'G you3',
#   'english': 'see 基友[ji1 you3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69fa')},
#  {'traditional': 'G弦褲',
#   'simplified': 'G弦裤',
#   'pinyin': 'G xian2 ku4',
#   'english': 'G-string',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69fb')},
#  {'traditional': 'G點',
#   'simplified': 'G点',
#   'pinyin': 'G dian3',
#   'english': 'G-spot',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69fc')},
#  {'traditional': 'H橋',
#   'simplified': 'H桥',
#   'pinyin': 'H qiao2',
#   'english': 'H bridge (electronics)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69fd')},
#  {'traditional': 'IP',
#   'simplified': 'IP',
#   'pinyin': 'I P',
#   'english': 'intellectual property (in China, esp. since 2015, often used as an entertainment industry term for a creative work used as the basis of a new product, such as a manga adapted as a tv series, or the image of a cartoon character appearing on merchandise)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69fe')},
#  {'traditional': 'IP劇',
#   'simplified': 'IP剧',
#   'pinyin': 'I P ju4',
#   'english': 'screen adaptation (TV series or movie based on an online novel or video game etc)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa69ff')},
#  {'traditional': 'JK製服',
#   'simplified': 'JK制服',
#   'pinyin': 'J K zhi4 fu2',
#   'english': '(Japanese) high school girl’s uniform',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a00')},
#  {'traditional': 'K人',
#   'simplified': 'K人',
#   'pinyin': 'K ren2',
#   'english': '(slang) to hit sb',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a01')},
#  {'traditional': 'K仔',
#   'simplified': 'K仔',
#   'pinyin': 'K zai3',
#   'english': 'ketamine (slang)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a02')},
#  {'traditional': 'K他命',
#   'simplified': 'K他命',
#   'pinyin': 'k ta1 ming4',
#   'english': 'ketamine (C13H16ClNO) (slang)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a03')},
#  {'traditional': 'K房',
#   'simplified': 'K房',
#   'pinyin': 'K fang2',
#   'english': '(slang) KTV',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a04')},
#  {'traditional': 'K書',
#   'simplified': 'K书',
#   'pinyin': 'K shu1',
#   'english': '(Tw) to cram (from Taiwanese 齧書, Tai-lo pr. [khè su], lit. to gnaw a book)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a05')},
#  {'traditional': 'K歌',
#   'simplified': 'K歌',
#   'pinyin': 'K ge1',
#   'english': 'karaoke (slang)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a06')},
#  {'traditional': 'K粉',
#   'simplified': 'K粉',
#   'pinyin': 'K fen3',
#   'english': 'ketamine (slang)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a07')},
#  {'traditional': 'K線',
#   'simplified': 'K线',
#   'pinyin': 'K xian4',
#   'english': 'candlestick (in a candlestick chart)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a08')},
#  {'traditional': 'K線圖',
#   'simplified': 'K线图',
#   'pinyin': 'K xian4 tu2',
#   'english': 'candlestick chart',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a09')},
#  {'traditional': 'K金',
#   'simplified': 'K金',
#   'pinyin': 'K jin1',
#   'english': 'see 開金|开金[kai1 jin1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a0a')},
#  {'traditional': 'L照',
#   'simplified': 'L照',
#   'pinyin': 'L zhao4',
#   'english': 'nude picture (from 裸照[luo3 zhao4])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a0b')},
#  {'traditional': 'MC',
#   'simplified': 'MC',
#   'pinyin': 'M C',
#   'english': '(Tw) (coll.) menstruation (from "menstrual cycle")',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a0c')},
#  {'traditional': 'MV',
#   'simplified': 'MV',
#   'pinyin': 'M V',
#   'english': 'desirability as a partner (abbr. for "mate value")',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a0d')},
#  {'traditional': 'M巾',
#   'simplified': 'M巾',
#   'pinyin': 'M jin1',
#   'english': '(coll.) menstrual pad',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a0e')},
#  {'traditional': 'NG',
#   'simplified': 'NG',
#   'pinyin': 'N G',
#   'english': '(loanword from Japanese "NG", an initialism for "no good") (film and TV) blooper',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a0f')},
#  {'traditional': 'NG片段',
#   'simplified': 'NG片段',
#   'pinyin': 'N G pian4 duan4',
#   'english': '(film and TV) blooper',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a10')},
#  {'traditional': 'NG鏡頭',
#   'simplified': 'NG镜头',
#   'pinyin': 'N G jing4 tou2',
#   'english': '(film and TV) blooper',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a11')},
#  {'traditional': 'N久',
#   'simplified': 'N久',
#   'pinyin': 'N jiu3',
#   'english': 'a very long time (etymology: in mathematics, n represents an arbitrarily large number)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a12')},
#  {'traditional': 'N擋',
#   'simplified': 'N挡',
#   'pinyin': 'N dang3',
#   'english': 'neutral (gear)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a13')},
#  {'traditional': 'OK繃',
#   'simplified': 'OK绷',
#   'pinyin': 'O K beng1',
#   'english': 'band-aid (Tw)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a14')},
#  {'traditional': 'OK鏡',
#   'simplified': 'OK镜',
#   'pinyin': 'O K jing4',
#   'english': 'OK lens, orthokeratology contact lens that helps reshape the cornea in order to eliminate nearsightedness or myopia',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a15')},
#  {'traditional': 'OS',
#   'simplified': 'OS',
#   'pinyin': 'O S',
#   'english': "(in a soap opera or movie) voice-over that makes a character's unspoken thoughts audible to the audience",
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a16')},
#  {'traditional': 'O型腿',
#   'simplified': 'O型腿',
#   'pinyin': 'O xing2 tui3',
#   'english': 'bow legs',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a17')},
#  {'traditional': 'P',
#   'simplified': 'P',
#   'pinyin': 'P',
#   'english': '(slang) femme (lesbian stereotype)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a18')},
#  {'traditional': 'PA',
#   'simplified': 'PA',
#   'pinyin': 'P A',
#   'english': 'public area attendant (tasked with cleaning the public areas of a hotel)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a19')},
#  {'traditional': 'PA部',
#   'simplified': 'PA部',
#   'pinyin': 'P A bu4',
#   'english': 'hotel staff work unit tasked with keeping the public areas of a hotel clean',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a1a')},
#  {'traditional': 'PK',
#   'simplified': 'PK',
#   'pinyin': 'P K',
#   'english': '(slang) to take on',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a1b')},
#  {'traditional': 'PO',
#   'simplified': 'PO',
#   'pinyin': 'po1',
#   'english': '(Tw) (coll.) to post (online)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a1c')},
#  {'traditional': 'PO文',
#   'simplified': 'PO文',
#   'pinyin': 'po1 wen2',
#   'english': '(coll.) to post a message',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a1d')},
#  {'traditional': 'PU',
#   'simplified': 'PU',
#   'pinyin': 'P U',
#   'english': 'the degree of suspicion that a woman might, after she marries, cheat on her husband (abbr. for "paternity uncertainty")',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a1e')},
#  {'traditional': 'PUA',
#   'simplified': 'PUA',
#   'pinyin': 'P U A',
#   'english': '(neologism c. 2019) to exert control over (sb) by means of psychological manipulation (e.g. negging)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a1f')},
#  {'traditional': 'P圖',
#   'simplified': 'P图',
#   'pinyin': 'P tu2',
#   'english': '(Internet slang) to photoshop a picture',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a20')},
#  {'traditional': 'P擋',
#   'simplified': 'P挡',
#   'pinyin': 'P dang3',
#   'english': 'park (gear)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a21')},
#  {'traditional': 'P民',
#   'simplified': 'P民',
#   'pinyin': 'P min2',
#   'english': '(slang) shitizen',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a22')},
#  {'traditional': 'Q',
#   'simplified': 'Q',
#   'pinyin': 'Q',
#   'english': 'cute (loanword)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a23')},
#  {'traditional': 'QR扣',
#   'simplified': 'QR扣',
#   'pinyin': 'Q R kou4',
#   'english': '(Tw) (loanword) QR code',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a24')},
#  {'traditional': 'Q勁',
#   'simplified': 'Q劲',
#   'pinyin': 'Q jin4',
#   'english': 'springy mouthfeel',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a25')},
#  {'traditional': 'Q彈',
#   'simplified': 'Q弹',
#   'pinyin': 'Q tan2',
#   'english': "(of a food's mouthfeel) springy",
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a26')},
#  {'traditional': 'T',
#   'simplified': 'T',
#   'pinyin': 'T',
#   'english': '(slang) butch (lesbian stereotype)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a27')},
#  {'traditional': 'TA',
#   'simplified': 'TA',
#   'pinyin': 'ta1',
#   'english': 'he or she',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a28')},
#  {'traditional': 'TF卡',
#   'simplified': 'TF卡',
#   'pinyin': 'T F ka3',
#   'english': 'microSD card',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a29')},
#  {'traditional': 'Tony',
#   'simplified': 'Tony',
#   'pinyin': 't o n y',
#   'english': '(slang) hairdresser',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a2a')},
#  {'traditional': 'Tony老師',
#   'simplified': 'Tony老师',
#   'pinyin': 't o n y lao3 shi1',
#   'english': '(slang) hairdresser',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a2b')},
#  {'traditional': 'T台',
#   'simplified': 'T台',
#   'pinyin': 'T tai2',
#   'english': 'runway (for a fashion show etc)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a2c')},
#  {'traditional': 'T型台',
#   'simplified': 'T型台',
#   'pinyin': 'T xing2 tai2',
#   'english': 'runway (for a fashion show etc)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a2d')},
#  {'traditional': 'T字帳',
#   'simplified': 'T字帐',
#   'pinyin': 'T zi4 zhang4',
#   'english': 'T-account (accounting)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a2e')},
#  {'traditional': 'T字褲',
#   'simplified': 'T字裤',
#   'pinyin': 'T zi4 ku4',
#   'english': 'thong (underwear)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a2f')},
#  {'traditional': 'T恤',
#   'simplified': 'T恤',
#   'pinyin': 'T xu4',
#   'english': 'T-shirt',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a30')},
#  {'traditional': 'T裇',
#   'simplified': 'T裇',
#   'pinyin': 'T xu1',
#   'english': 'T-shirt',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a31')},
#  {'traditional': 'UP主',
#   'simplified': 'UP主',
#   'pinyin': 'U P zhu3',
#   'english': '(Internet slang) uploader (person who uploads a video or other content to the Internet)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a32')},
#  {'traditional': 'USB手指',
#   'simplified': 'USB手指',
#   'pinyin': 'U S B shou3 zhi3',
#   'english': 'USB flash drive',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a33')},
#  {'traditional': 'USB記憶棒',
#   'simplified': 'USB记忆棒',
#   'pinyin': 'U S B ji4 yi4 bang4',
#   'english': 'USB flash drive',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a34')},
#  {'traditional': 'U凸內褲',
#   'simplified': 'U凸内裤',
#   'pinyin': 'U tu1 nei4 ku4',
#   'english': "contour pouch brief (men's underwear)",
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a35')},
#  {'traditional': 'U型枕',
#   'simplified': 'U型枕',
#   'pinyin': 'U xing2 zhen3',
#   'english': 'travel pillow',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a36')},
#  {'traditional': 'U型池',
#   'simplified': 'U型池',
#   'pinyin': 'U xing2 chi2',
#   'english': '(sports) vert ramp',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a37')},
#  {'traditional': 'U形轉彎',
#   'simplified': 'U形转弯',
#   'pinyin': 'U xing2 zhuan3 wan1',
#   'english': 'U-turn',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a38')},
#  {'traditional': 'U盤',
#   'simplified': 'U盘',
#   'pinyin': 'U pan2',
#   'english': 'USB flash drive',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a39')},
#  {'traditional': 'U盾',
#   'simplified': 'U盾',
#   'pinyin': 'U dun4',
#   'english': 'USB key used as a security token in Chinese online banking',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a3a')},
#  {'traditional': 'VCR',
#   'simplified': 'VCR',
#   'pinyin': 'V C R',
#   'english': 'video clip (loanword from "videocassette recorder")',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a3b')},
#  {'traditional': 'V溝',
#   'simplified': 'V沟',
#   'pinyin': 'V gou1',
#   'english': 'low neckline that reveals the cleavage',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a3c')},
#  {'traditional': 'XO醬',
#   'simplified': 'XO酱',
#   'pinyin': 'X O jiang4',
#   'english': 'XO sauce, a spicy seafood sauce invented in Hong Kong in the 1980s',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a3d')},
#  {'traditional': 'X光',
#   'simplified': 'X光',
#   'pinyin': 'X guang1',
#   'english': 'X-ray',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a3e')},
#  {'traditional': 'cos',
#   'simplified': 'cos',
#   'pinyin': 'c o s',
#   'english': '(Internet slang) cosplay',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a3f')},
#  {'traditional': 'ins',
#   'simplified': 'ins',
#   'pinyin': 'i n s',
#   'english': 'Instagram',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a40')},
#  {'traditional': 'mua',
#   'simplified': 'mua',
#   'pinyin': 'm u a',
#   'english': '(onom.) mwah (sound of a kiss)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a41')},
#  {'traditional': 'w',
#   'simplified': 'w',
#   'pinyin': 'w',
#   'english': '(Internet slang) ten thousand (abbr. for 萬|万[wan4])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a42')},
#  {'traditional': 'word',
#   'simplified': 'word',
#   'pinyin': 'w o r d',
#   'english': 'my (Internet slang variant of 我的[wo3 de5])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a43')},
#  {'traditional': 'word姐',
#   'simplified': 'word姐',
#   'pinyin': 'w o r d jie3',
#   'english': 'my big sister (Internet slang version of 我的姐[wo3 de5 jie3])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a44')},
#  {'traditional': 'π日',
#   'simplified': 'π日',
#   'pinyin': 'Pai4 ri4',
#   'english': 'World Pi Day, a celebration of the mathematical constant π on March 14 each year',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a45')},
#  {'traditional': '□',
#   'simplified': '□',
#   'pinyin': 'biang4',
#   'english': '(Tw) (coll.) cool',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a46')},
#  {'traditional': '□',
#   'simplified': '□',
#   'pinyin': 'biu1',
#   'english': '(onom.) pew! (sound of a bullet fired from a gun)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a47')},
#  {'traditional': '□',
#   'simplified': '□',
#   'pinyin': 'ging1',
#   'english': 'uptight',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a48')},
#  {'traditional': '○',
#   'simplified': '○',
#   'pinyin': 'ling2',
#   'english': 'character used in Taiwan as a substitute for a real name (like "X" in English)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a49')},
#  {'traditional': '⺮',
#   'simplified': '⺮',
#   'pinyin': 'zhu2',
#   'english': '"bamboo" radical in Chinese characters (Kangxi radical 118)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a4a')},
#  {'traditional': '々',
#   'simplified': '々',
#   'pinyin': 'xx5',
#   'english': 'iteration mark (used to represent a duplicated character)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a4b')},
#  {'traditional': '〇',
#   'simplified': '〇',
#   'pinyin': 'ling2',
#   'english': 'zero',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a4c')},
#  {'traditional': '〡',
#   'simplified': '〡',
#   'pinyin': 'yi1',
#   'english': 'numeral 1 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a4d')},
#  {'traditional': '〢',
#   'simplified': '〢',
#   'pinyin': 'er4',
#   'english': 'numeral 2 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a4e')},
#  {'traditional': '〣',
#   'simplified': '〣',
#   'pinyin': 'san1',
#   'english': 'numeral 3 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a4f')},
#  {'traditional': '〤',
#   'simplified': '〤',
#   'pinyin': 'si4',
#   'english': 'numeral 4 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a50')},
#  {'traditional': '〥',
#   'simplified': '〥',
#   'pinyin': 'wu3',
#   'english': 'numeral 5 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a51')},
#  {'traditional': '〦',
#   'simplified': '〦',
#   'pinyin': 'liu4',
#   'english': 'numeral 6 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a52')},
#  {'traditional': '〧',
#   'simplified': '〧',
#   'pinyin': 'qi1',
#   'english': 'numeral 7 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a53')},
#  {'traditional': '〨',
#   'simplified': '〨',
#   'pinyin': 'ba1',
#   'english': 'numeral 8 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a54')},
#  {'traditional': '〩',
#   'simplified': '〩',
#   'pinyin': 'jiu3',
#   'english': 'numeral 9 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a55')},
#  {'traditional': '〸',
#   'simplified': '〸',
#   'pinyin': 'shi2',
#   'english': 'numeral 10 in Suzhou numeral system 蘇州碼子|苏州码子[Su1 zhou1 ma3 zi5]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a56')},
#  {'traditional': '〻',
#   'simplified': '〻',
#   'pinyin': 'xx5',
#   'english': 'iteration mark (used to represent a duplicated character)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a57')},
#  {'traditional': 'ㄅㄧㄤˋ',
#   'simplified': 'ㄅㄧㄤˋ',
#   'pinyin': 'xx5 xx5 xx5 xx5',
#   'english': '(Tw) (coll.) cool',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a58')},
#  {'traditional': '㍻',
#   'simplified': '㍻',
#   'pinyin': 'xx5',
#   'english': '平成[Ping2 cheng2] written as a single character',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a59')},
#  {'traditional': '㍼',
#   'simplified': '㍼',
#   'pinyin': 'xx5',
#   'english': '昭和[Zhao1 he2] written as a single character',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a5a')},
#  {'traditional': '㍽',
#   'simplified': '㍽',
#   'pinyin': 'xx5',
#   'english': '大正[Da4 zheng4] written as a single character',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a5b')},
#  {'traditional': '㍾',
#   'simplified': '㍾',
#   'pinyin': 'xx5',
#   'english': '明治[Ming2 zhi4] written as a single character',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a5c')},
#  {'traditional': '㐄',
#   'simplified': '㐄',
#   'pinyin': 'kua4',
#   'english': 'component in Chinese characters, mirror image of 夂[zhi3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a5d')},
#  {'traditional': '㐅',
#   'simplified': '㐅',
#   'pinyin': 'wu3',
#   'english': 'archaic variant of 五[wu3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a5e')},
#  {'traditional': '㐆',
#   'simplified': '㐆',
#   'pinyin': 'yin3',
#   'english': 'component in Chinese character 殷[yin1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a5f')},
#  {'traditional': '㐌',
#   'simplified': '㐌',
#   'pinyin': 'ta1',
#   'english': 'variant of 它[ta1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a60')},
#  {'traditional': '㐖',
#   'simplified': '㐖',
#   'pinyin': 'xie2',
#   'english': 'used in 㐖毒[Xie2 du2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a61')},
#  {'traditional': '㐖毒',
#   'simplified': '㐖毒',
#   'pinyin': 'Xie2 du2',
#   'english': 'India (archaic)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a62')},
#  {'traditional': '㐜',
#   'simplified': '㐜',
#   'pinyin': 'chou2',
#   'english': 'variant of 仇[chou2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a63')},
#  {'traditional': '㐡',
#   'simplified': '㐡',
#   'pinyin': 'nuo4',
#   'english': 'archaic variant of 懦[nuo4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a64')},
#  {'traditional': '㐤',
#   'simplified': '㐤',
#   'pinyin': 'qiu2',
#   'english': 'archaic variant of 求[qiu2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a65')},
#  {'traditional': '㐫',
#   'simplified': '㐫',
#   'pinyin': 'xiong1',
#   'english': 'old variant of 凶[xiong1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a66')},
#  {'traditional': '㐰',
#   'simplified': '㐰',
#   'pinyin': 'xin4',
#   'english': 'old variant of 信[xin4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a67')},
#  {'traditional': '㐺',
#   'simplified': '㐺',
#   'pinyin': 'zhong4',
#   'english': 'old variant of 眾|众[zhong4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a68')},
#  {'traditional': '㑊',
#   'simplified': '㑊',
#   'pinyin': 'yi4',
#   'english': 'used in 解㑊[xie4 yi4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a69')},
#  {'traditional': '㑳',
#   'simplified': '㑇',
#   'pinyin': 'zhou4',
#   'english': '(old) beautiful',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a6a')},
#  {'traditional': '㑺',
#   'simplified': '俊',
#   'pinyin': 'jun4',
#   'english': 'old variant of 俊[jun4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a6b')},
#  {'traditional': '㒳',
#   'simplified': '㒳',
#   'pinyin': 'liang3',
#   'english': 'old variant of 兩|两[liang3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a6c')},
#  {'traditional': '㒸',
#   'simplified': '㒸',
#   'pinyin': 'sui4',
#   'english': 'archaic variant of 遂[sui4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a6d')},
#  {'traditional': '㒺',
#   'simplified': '罔',
#   'pinyin': 'wang3',
#   'english': 'old variant of 罔[wang3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a6e')},
#  {'traditional': '㓂',
#   'simplified': '寇',
#   'pinyin': 'kou4',
#   'english': 'old variant of 寇[kou4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a6f')},
#  {'traditional': '㔾',
#   'simplified': '㔾',
#   'pinyin': 'jie2',
#   'english': '"seal" radical in Chinese characters (Kangxi radical 26)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a70')},
#  {'traditional': '㕁',
#   'simplified': '却',
#   'pinyin': 'que4',
#   'english': 'old variant of 卻|却[que4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a71')},
#  {'traditional': '㕑',
#   'simplified': '厨',
#   'pinyin': 'chu2',
#   'english': 'old variant of 廚|厨[chu2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a72')},
#  {'traditional': '㕘',
#   'simplified': '参',
#   'pinyin': 'can1',
#   'english': 'variant of 參|参[can1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a73')},
#  {'traditional': '㕥',
#   'simplified': '㕥',
#   'pinyin': 'shen1',
#   'english': 'old variant of 呻[shen1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a74')},
#  {'traditional': '㕥',
#   'simplified': '以',
#   'pinyin': 'yi3',
#   'english': 'old variant of 以[yi3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a75')},
#  {'traditional': '㕯',
#   'simplified': '㕯',
#   'pinyin': 'ne4',
#   'english': 'old variant of 訥|讷[ne4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a76')},
#  {'traditional': '㕻',
#   'simplified': '㕻',
#   'pinyin': 'pou3',
#   'english': 'variant of 咅[pou3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a77')},
#  {'traditional': '㗂',
#   'simplified': '㗂',
#   'pinyin': 'sheng3',
#   'english': 'variant of 省[sheng3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a78')},
#  {'traditional': '㘚',
#   'simplified': '㘎',
#   'pinyin': 'han3',
#   'english': '(literary) (of a tiger) to growl',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a79')},
#  {'traditional': '㘭',
#   'simplified': '坳',
#   'pinyin': 'ao4',
#   'english': 'variant of 坳[ao4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a7a')},
#  {'traditional': '㙍',
#   'simplified': '㙍',
#   'pinyin': 'duo1',
#   'english': '(used in place names)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a7b')},
#  {'traditional': '㙦',
#   'simplified': '㙦',
#   'pinyin': 'xie2',
#   'english': '(used in place names)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a7c')},
#  {'traditional': '㚻',
#   'simplified': '㚻',
#   'pinyin': 'ji1',
#   'english': 'used in 㚻姦|㚻奸[ji1 jian1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a7d')},
#  {'traditional': '㚻姦',
#   'simplified': '㚻奸',
#   'pinyin': 'ji1 jian1',
#   'english': 'variant of 雞奸|鸡奸[ji1 jian1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a7e')},
#  {'traditional': '㛂',
#   'simplified': '㛂',
#   'pinyin': 'nuo3',
#   'english': 'graceful',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a7f')},
#  {'traditional': '㛃',
#   'simplified': '㛃',
#   'pinyin': 'jie2',
#   'english': 'variant of 潔|洁[jie2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a80')},
#  {'traditional': '㝄',
#   'simplified': '㝄',
#   'pinyin': 'chun2',
#   'english': 'old variant of 純|纯[chun2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a81')},
#  {'traditional': '㝇',
#   'simplified': '㝇',
#   'pinyin': 'chun2',
#   'english': 'old variant of 鶉|鹑[chun2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a82')},
#  {'traditional': '㝛',
#   'simplified': '宿',
#   'pinyin': 'su4',
#   'english': 'old variant of 宿[su4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a83')},
#  {'traditional': '㝠',
#   'simplified': '冥',
#   'pinyin': 'ming2',
#   'english': 'old variant of 冥[ming2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a84')},
#  {'traditional': '㝡',
#   'simplified': '最',
#   'pinyin': 'zui4',
#   'english': 'variant of 最[zui4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a85')},
#  {'traditional': '㝵',
#   'simplified': '㝵',
#   'pinyin': 'ai4',
#   'english': 'variant of 礙|碍[ai4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a86')},
#  {'traditional': '㝵',
#   'simplified': '㝵',
#   'pinyin': 'de2',
#   'english': 'to obtain',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a87')},
#  {'traditional': '㞎',
#   'simplified': '㞎',
#   'pinyin': 'ba3',
#   'english': '(baby talk) poop',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a88')},
#  {'traditional': '㞎㞎',
#   'simplified': '㞎㞎',
#   'pinyin': 'ba3 ba5',
#   'english': '(baby talk) poop',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a89')},
#  {'traditional': '㞗',
#   'simplified': '㞗',
#   'pinyin': 'qiu2',
#   'english': '(dialect) penis',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a8a')},
#  {'traditional': '㞙',
#   'simplified': '㞙',
#   'pinyin': 'niao4',
#   'english': 'old variant of 尿[niao4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a8b')},
#  {'traditional': '㞞',
#   'simplified': '𪨊',
#   'pinyin': 'song2',
#   'english': '(coll.) semen',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a8c')},
#  {'traditional': '㟁',
#   'simplified': '岸',
#   'pinyin': 'an4',
#   'english': 'variant of 岸[an4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a8d')},
#  {'traditional': '㟃',
#   'simplified': '㟃',
#   'pinyin': 'si1',
#   'english': '(used in place names)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a8e')},
#  {'traditional': '㠀',
#   'simplified': '岛',
#   'pinyin': 'dao3',
#   'english': 'variant of 島|岛[dao3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a8f')},
#  {'traditional': '㠇',
#   'simplified': '㠇',
#   'pinyin': 'jiu4',
#   'english': '(name of a mountain ridge)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a90')},
#  {'traditional': '㠯',
#   'simplified': '以',
#   'pinyin': 'yi3',
#   'english': 'old variant of 以[yi3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a91')},
#  {'traditional': '㠶',
#   'simplified': '帆',
#   'pinyin': 'fan1',
#   'english': 'variant of 帆[fan1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a92')},
#  {'traditional': '㡌',
#   'simplified': '帽',
#   'pinyin': 'mao4',
#   'english': 'old variant of 帽[mao4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a93')},
#  {'traditional': '㢘',
#   'simplified': '廉',
#   'pinyin': 'lian2',
#   'english': 'old variant of 廉[lian2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a94')},
#  {'traditional': '㢠',
#   'simplified': '迥',
#   'pinyin': 'jiong3',
#   'english': 'variant of 迥[jiong3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a95')},
#  {'traditional': '㢲',
#   'simplified': '㢲',
#   'pinyin': 'xun4',
#   'english': 'variant of 巽[xun4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a96')},
#  {'traditional': '㢴',
#   'simplified': '㢴',
#   'pinyin': 'xi1',
#   'english': 'old variant of 西[xi1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a97')},
#  {'traditional': '㣟',
#   'simplified': '㣟',
#   'pinyin': 'xi4',
#   'english': 'to go',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a98')},
#  {'traditional': '㤅',
#   'simplified': '㤅',
#   'pinyin': 'ai4',
#   'english': 'archaic variant of 愛|爱[ai4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a99')},
#  {'traditional': '㤙',
#   'simplified': '恩',
#   'pinyin': 'en1',
#   'english': 'variant of 恩[en1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a9a')},
#  {'traditional': '㥁',
#   'simplified': '㥁',
#   'pinyin': 'de2',
#   'english': 'variant of 德[de2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a9b')},
#  {'traditional': '㥏',
#   'simplified': '㥏',
#   'pinyin': 'tian3',
#   'english': 'ashamed',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a9c')},
#  {'traditional': '㥦',
#   'simplified': '惬',
#   'pinyin': 'qie4',
#   'english': 'variant of 愜|惬[qie4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a9d')},
#  {'traditional': '㥮',
#   'simplified': '㤘',
#   'pinyin': 'zhou4',
#   'english': '(dialect) stubborn',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a9e')},
#  {'traditional': '㥯',
#   'simplified': '㥯',
#   'pinyin': 'yin3',
#   'english': 'cautious',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6a9f')},
#  {'traditional': '㦂',
#   'simplified': '㦂',
#   'pinyin': 'chang2',
#   'english': 'old variant of 常[chang2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa0')},
#  {'traditional': '㧯',
#   'simplified': '㧯',
#   'pinyin': 'lao3',
#   'english': 'round-bottomed wicker basket',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa1')},
#  {'traditional': '㧱',
#   'simplified': '拿',
#   'pinyin': 'na2',
#   'english': 'old variant of 拿[na2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa2')},
#  {'traditional': '㨃',
#   'simplified': '㨃',
#   'pinyin': 'dui3',
#   'english': 'variant of 懟|怼[dui3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa3')},
#  {'traditional': '㨗',
#   'simplified': '捷',
#   'pinyin': 'jie2',
#   'english': 'variant of 捷[jie2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa4')},
#  {'traditional': '㨪',
#   'simplified': '晃',
#   'pinyin': 'huang3',
#   'english': 'variant of 晃[huang3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa5')},
#  {'traditional': '㨿',
#   'simplified': '据',
#   'pinyin': 'ju4',
#   'english': 'variant of 據|据[ju4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa6')},
#  {'traditional': '㩐',
#   'simplified': '㩐',
#   'pinyin': 'den4',
#   'english': 'variant of 扽[den4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa7')},
#  {'traditional': '㩗',
#   'simplified': '携',
#   'pinyin': 'xie2',
#   'english': 'old variant of 攜|携[xie2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa8')},
#  {'traditional': '㩜',
#   'simplified': '㨫',
#   'pinyin': 'lan3',
#   'english': 'variant of 擥[lan3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aa9')},
#  {'traditional': '㩦',
#   'simplified': '携',
#   'pinyin': 'xie2',
#   'english': 'old variant of 攜|携[xie2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aaa')},
#  {'traditional': '㩳',
#   'simplified': '㧐',
#   'pinyin': 'song3',
#   'english': '(literary) to stand upright',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aab')},
#  {'traditional': '㪃',
#   'simplified': '㪃',
#   'pinyin': 'he2',
#   'english': 'to beat',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aac')},
#  {'traditional': '㪋',
#   'simplified': '㪋',
#   'pinyin': 'han4',
#   'english': 'variant of 捍[han4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aad')},
#  {'traditional': '㪚',
#   'simplified': '散',
#   'pinyin': 'san4',
#   'english': 'variant of 散[san4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aae')},
#  {'traditional': '㪟',
#   'simplified': '敦',
#   'pinyin': 'dun1',
#   'english': 'variant of 敦[dun1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aaf')},
#  {'traditional': '㫰',
#   'simplified': '㫰',
#   'pinyin': 'lang4',
#   'english': '(dialect) to dry (sth) in the sun',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab0')},
#  {'traditional': '㫺',
#   'simplified': '㫺',
#   'pinyin': 'xi1',
#   'english': 'old variant of 昔[xi1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab1')},
#  {'traditional': '㬉',
#   'simplified': '暖',
#   'pinyin': 'nuan3',
#   'english': 'old variant of 暖[nuan3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab2')},
#  {'traditional': '㬎',
#   'simplified': '㬎',
#   'pinyin': 'xian3',
#   'english': 'old variant of 顯|显[xian3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab3')},
#  {'traditional': '㮎',
#   'simplified': '㮎',
#   'pinyin': 'bei1',
#   'english': 'variant of 杯[bei1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab4')},
#  {'traditional': '㮚',
#   'simplified': '㮚',
#   'pinyin': 'li4',
#   'english': 'old variant of 栗[li4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab5')},
#  {'traditional': '㮸',
#   'simplified': '㮸',
#   'pinyin': 'song4',
#   'english': 'variant of 送[song4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab6')},
#  {'traditional': '㯭',
#   'simplified': '橹',
#   'pinyin': 'lu3',
#   'english': 'variant of 櫓|橹[lu3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab7')},
#  {'traditional': '㯳',
#   'simplified': '㯳',
#   'pinyin': 'qing2',
#   'english': 'variant of 檠[qing2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab8')},
#  {'traditional': '㱃',
#   'simplified': '饮',
#   'pinyin': 'yin3',
#   'english': 'old variant of 飲|饮[yin3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ab9')},
#  {'traditional': '㱾',
#   'simplified': '㱾',
#   'pinyin': 'gai1',
#   'english': 'a kind of metal or jade ornament worn in ancient times to ward off evil spirits',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aba')},
#  {'traditional': '㲈',
#   'simplified': '㲈',
#   'pinyin': 'shao2',
#   'english': 'variant of 韶[shao2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6abb')},
#  {'traditional': '㲈',
#   'simplified': '㲈',
#   'pinyin': 'tao2',
#   'english': 'variant of 鞀|鼗[tao2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6abc')},
#  {'traditional': '㲋',
#   'simplified': '㲋',
#   'pinyin': 'chuo4',
#   'english': 'ancient name for an animal similar to rabbit but bigger',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6abd')},
#  {'traditional': '㲱',
#   'simplified': '㲱',
#   'pinyin': 'lie4',
#   'english': 'old variant of 鬣[lie4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6abe')},
#  {'traditional': '㲾',
#   'simplified': '㲾',
#   'pinyin': 'yu3',
#   'english': 'old variant of 雨[yu3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6abf')},
#  {'traditional': '㳂',
#   'simplified': '㳂',
#   'pinyin': 'yan2',
#   'english': 'variant of 沿[yan2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac0')},
#  {'traditional': '㳄',
#   'simplified': '涎',
#   'pinyin': 'xian2',
#   'english': 'variant of 涎[xian2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac1')},
#  {'traditional': '㳇',
#   'simplified': '㳇',
#   'pinyin': 'fu4',
#   'english': '(used in place names)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac2')},
#  {'traditional': '㳒',
#   'simplified': '法',
#   'pinyin': 'fa3',
#   'english': 'variant of 法[fa3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac3')},
#  {'traditional': '㳘',
#   'simplified': '㳘',
#   'pinyin': 'chong1',
#   'english': '(literary) (of a mountain stream) to flow down',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac4')},
#  {'traditional': '㳮',
#   'simplified': '㳮',
#   'pinyin': 'niao4',
#   'english': 'old variant of 尿[niao4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac5')},
#  {'traditional': '㴱',
#   'simplified': '深',
#   'pinyin': 'shen1',
#   'english': 'old variant of 深[shen1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac6')},
#  {'traditional': '㵎',
#   'simplified': '涧',
#   'pinyin': 'jian4',
#   'english': 'variant of 澗|涧[jian4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac7')},
#  {'traditional': '㵐',
#   'simplified': '㵐',
#   'pinyin': 'Jue2',
#   'english': 'Jue River in Hubei',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac8')},
#  {'traditional': '㵐水',
#   'simplified': '㵐水',
#   'pinyin': 'Jue2 Shui3',
#   'english': 'Jue River in Hubei',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ac9')},
#  {'traditional': '㵪',
#   'simplified': '㵪',
#   'pinyin': 'xian2',
#   'english': 'variant of 涎[xian2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aca')},
#  {'traditional': '㵮',
#   'simplified': '㵮',
#   'pinyin': 'chun2',
#   'english': 'clear water',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6acb')},
#  {'traditional': '㶸',
#   'simplified': '㶸',
#   'pinyin': 'xie2',
#   'english': '(precise meaning unknown, relates to iron)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6acc')},
#  {'traditional': '㷖',
#   'simplified': '㷖',
#   'pinyin': 'zhao4',
#   'english': 'old variant of 照[zhao4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6acd')},
#  {'traditional': '㷭',
#   'simplified': '㷭',
#   'pinyin': 'feng1',
#   'english': 'old variant of 烽[feng1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ace')},
#  {'traditional': '㷸',
#   'simplified': '烨',
#   'pinyin': 'ye4',
#   'english': 'variant of 燁|烨[ye4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6acf')},
#  {'traditional': '㸌',
#   'simplified': '㸌',
#   'pinyin': 'huo4',
#   'english': 'to twinkle',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad0')},
#  {'traditional': '㹠',
#   'simplified': '㹠',
#   'pinyin': 'tun2',
#   'english': 'old variant of 豚[tun2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad1')},
#  {'traditional': '㹢',
#   'simplified': '㹢',
#   'pinyin': 'jia1',
#   'english': 'used in the transcription of "okapi" 㺢㹢狓[huo4 jia1 pi1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad2')},
#  {'traditional': '㹴',
#   'simplified': '㹴',
#   'pinyin': 'geng3',
#   'english': 'fierce dog',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad3')},
#  {'traditional': '㹴犬',
#   'simplified': '㹴犬',
#   'pinyin': 'geng3 quan3',
#   'english': 'variant of 梗犬[geng3 quan3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad4')},
#  {'traditional': '㺢',
#   'simplified': '㺢',
#   'pinyin': 'huo4',
#   'english': 'used in the transcription of "okapi" 㺢㹢狓[huo4 jia1 pi1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad5')},
#  {'traditional': '㺢㹢狓',
#   'simplified': '㺢㹢狓',
#   'pinyin': 'huo4 jia1 pi1',
#   'english': 'okapi (Okapia johnstoni)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad6')},
#  {'traditional': '㺵',
#   'simplified': '㺵',
#   'pinyin': 'jiu3',
#   'english': 'variant of 玖[jiu3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad7')},
#  {'traditional': '㻬',
#   'simplified': '㻬',
#   'pinyin': 'tu2',
#   'english': 'a kind of jade',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad8')},
#  {'traditional': '㻽',
#   'simplified': '㻽',
#   'pinyin': 'xuan2',
#   'english': 'variant of 璿|璇[xuan2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ad9')},
#  {'traditional': '㼝',
#   'simplified': '碗',
#   'pinyin': 'wan3',
#   'english': 'variant of 碗[wan3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ada')},
#  {'traditional': '㽞',
#   'simplified': '留',
#   'pinyin': 'liu2',
#   'english': 'old variant of 留[liu2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6adb')},
#  {'traditional': '㽮',
#   'simplified': '㽮',
#   'pinyin': 'xing1',
#   'english': 'old variant of 星[xing1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6adc')},
#  {'traditional': '㿜',
#   'simplified': '瘪',
#   'pinyin': 'bie3',
#   'english': 'variant of 癟|瘪[bie3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6add')},
#  {'traditional': '㿝',
#   'simplified': '㿝',
#   'pinyin': 'xiang1',
#   'english': 'old variant of 香[xiang1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ade')},
#  {'traditional': '㿠',
#   'simplified': '㿠',
#   'pinyin': 'huang4',
#   'english': '(literary) (of the face) pale due to qi and blood deficiency',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6adf')},
#  {'traditional': '䂖',
#   'simplified': '䂖',
#   'pinyin': 'shi2',
#   'english': 'variant of 石[shi2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae0')},
#  {'traditional': '䂲',
#   'simplified': '䂲',
#   'pinyin': 'fa3',
#   'english': 'variant of 砝[fa3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae1')},
#  {'traditional': '䂶',
#   'simplified': '䂶',
#   'pinyin': 'jie2',
#   'english': 'variant of 蜐[jie2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae2')},
#  {'traditional': '䃉',
#   'simplified': '䃉',
#   'pinyin': 'min2',
#   'english': 'old variant of 珉[min2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae3')},
#  {'traditional': '䃎',
#   'simplified': '䃎',
#   'pinyin': 'zha4',
#   'english': '(used in place names)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae4')},
#  {'traditional': '䅵',
#   'simplified': '䅵',
#   'pinyin': 'zhuo2',
#   'english': 'chaff',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae5')},
#  {'traditional': '䇲',
#   'simplified': '䇲',
#   'pinyin': 'ce4',
#   'english': 'variant of 筴|策[ce4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae6')},
#  {'traditional': '䈰',
#   'simplified': '筲',
#   'pinyin': 'shao1',
#   'english': 'pot-scrubbing brush made of bamboo strips',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae7')},
#  {'traditional': '䊀',
#   'simplified': '糊',
#   'pinyin': 'hu2',
#   'english': 'variant of 糊[hu2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae8')},
#  {'traditional': '䍃',
#   'simplified': '䍃',
#   'pinyin': 'yao2',
#   'english': '(archaic) vase',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6ae9')},
#  {'traditional': '䍹',
#   'simplified': '䍹',
#   'pinyin': 'shan1',
#   'english': 'variant of 羶[shan1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aea')},
#  {'traditional': '䎃',
#   'simplified': '䎃',
#   'pinyin': 'ran3',
#   'english': '(ornithology) down',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aeb')},
#  {'traditional': '䒗',
#   'simplified': '䒗',
#   'pinyin': 'qi4',
#   'english': 'old variant of 芞[qi4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aec')},
#  {'traditional': '䓬',
#   'simplified': '䓬',
#   'pinyin': 'zhuo2',
#   'english': '(chemistry) tropylium ion',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aed')},
#  {'traditional': '䔢',
#   'simplified': '䔢',
#   'pinyin': 'hua2',
#   'english': 'old variant of 華|华[hua2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aee')},
#  {'traditional': '䕭',
#   'simplified': '䕭',
#   'pinyin': 'qian2',
#   'english': 'a variety of grass',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aef')},
#  {'traditional': '䕭',
#   'simplified': '䕭',
#   'pinyin': 'xian2',
#   'english': 'a kind of vegetable',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af0')},
#  {'traditional': '䖟',
#   'simplified': '䖟',
#   'pinyin': 'meng2',
#   'english': 'old variant of 虻[meng2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af1')},
#  {'traditional': '䖸',
#   'simplified': '䖸',
#   'pinyin': 'e2',
#   'english': 'variant of 蛾[e2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af2')},
#  {'traditional': '䗈',
#   'simplified': '䗈',
#   'pinyin': 'meng2',
#   'english': 'old variant of 虻[meng2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af3')},
#  {'traditional': '䗥',
#   'simplified': '䗥',
#   'pinyin': 'zong1',
#   'english': 'used in 螉䗥[weng1 zong1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af4')},
#  {'traditional': '䗪',
#   'simplified': '䗪',
#   'pinyin': 'zhe4',
#   'english': 'Chinese ground beetle (Eupolyphaga sinensis)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af5')},
#  {'traditional': '䗬',
#   'simplified': '蜂',
#   'pinyin': 'feng1',
#   'english': 'variant of 蜂[feng1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af6')},
#  {'traditional': '䗶',
#   'simplified': '䗶',
#   'pinyin': 'la4',
#   'english': 'old variant of 蠟|蜡[la4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af7')},
#  {'traditional': '䘏',
#   'simplified': '恤',
#   'pinyin': 'xu4',
#   'english': 'variant of 恤[xu4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af8')},
#  {'traditional': '䘑',
#   'simplified': '脉',
#   'pinyin': 'mai4',
#   'english': 'old variant of 脈|脉[mai4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6af9')},
#  {'traditional': '䘚',
#   'simplified': '卒',
#   'pinyin': 'zu2',
#   'english': 'variant of 卒[zu2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6afa')},
#  {'traditional': '䛐',
#   'simplified': '词',
#   'pinyin': 'ci2',
#   'english': 'old variant of 詞|词[ci2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6afb')},
#  {'traditional': '䛟',
#   'simplified': '䛟',
#   'pinyin': 'jia2',
#   'english': 'variant of 唊[jia2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6afc')},
#  {'traditional': '䝓',
#   'simplified': '䝓',
#   'pinyin': 'lie4',
#   'english': 'old variant of 鬣[lie4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6afd')},
#  {'traditional': '䝔',
#   'simplified': '獾',
#   'pinyin': 'huan1',
#   'english': 'variant of 獾[huan1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6afe')},
#  {'traditional': '䞓',
#   'simplified': '䞓',
#   'pinyin': 'cheng1',
#   'english': 'old variant of 赬|赪[cheng1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6aff')},
#  {'traditional': '䟆',
#   'simplified': '䟆',
#   'pinyin': 'bi4',
#   'english': 'old variant of 蹕|跸[bi4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6b00')},
#  {'traditional': '䟖',
#   'simplified': '䟖',
#   'pinyin': 'zhi3',
# ...
#   'english': 'not worth a penny',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d65')},
#  {'traditional': '一錢如命',
#   'simplified': '一钱如命',
#   'pinyin': 'yi1 qian2 ru2 ming4',
#   'english': 'stingy',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d66')},
#  {'traditional': '一錯再錯',
#   'simplified': '一错再错',
#   'pinyin': 'yi1 cuo4 zai4 cuo4',
#   'english': 'to repeat errors',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d67')},
#  {'traditional': '一鍋端',
#   'simplified': '一锅端',
#   'pinyin': 'yi1 guo1 duan1',
#   'english': 'see 連鍋端|连锅端[lian2 guo1 duan1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d68')},
#  {'traditional': '一鍋粥',
#   'simplified': '一锅粥',
#   'pinyin': 'yi1 guo1 zhou1',
#   'english': '(lit.) a pot of porridge',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d69')},
#  {'traditional': '一長一短',
#   'simplified': '一长一短',
#   'pinyin': 'yi1 chang2 yi1 duan3',
#   'english': 'talking endlessly',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d6a')},
#  {'traditional': '一門式',
#   'simplified': '一门式',
#   'pinyin': 'yi1 men2 shi4',
#   'english': 'one-stop (service, shop etc)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d6b')},
#  {'traditional': '一門心思',
#   'simplified': '一门心思',
#   'pinyin': 'yi1 men2 xin1 si5',
#   'english': "to set one's heart on sth (idiom)",
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d6c')},
#  {'traditional': '一閃念',
#   'simplified': '一闪念',
#   'pinyin': 'yi1 shan3 nian4',
#   'english': 'sudden idea',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d6d')},
#  {'traditional': '一閃而過',
#   'simplified': '一闪而过',
#   'pinyin': 'yi1 shan3 er2 guo4',
#   'english': 'to flash past',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d6e')},
#  {'traditional': '一陣',
#   'simplified': '一阵',
#   'pinyin': 'yi1 zhen4',
#   'english': 'a burst',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d6f')},
#  {'traditional': '一陣子',
#   'simplified': '一阵子',
#   'pinyin': 'yi1 zhen4 zi5',
#   'english': 'a while',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d70')},
#  {'traditional': '一雨成秋',
#   'simplified': '一雨成秋',
#   'pinyin': 'yi1 yu3 cheng2 qiu1',
#   'english': 'a sudden shower towards the end of summer brings an abrupt arrival of autumn (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d71')},
#  {'traditional': '一雪前恥',
#   'simplified': '一雪前耻',
#   'pinyin': 'yi1 xue3 qian2 chi3',
#   'english': 'to wipe away a humiliation (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d72')},
#  {'traditional': '一霎',
#   'simplified': '一霎',
#   'pinyin': 'yi1 sha4',
#   'english': 'in a flash',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d73')},
#  {'traditional': '一霎時',
#   'simplified': '一霎时',
#   'pinyin': 'yi1 sha4 shi2',
#   'english': 'in an instant',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d74')},
#  {'traditional': '一霎眼',
#   'simplified': '一霎眼',
#   'pinyin': 'yi1 sha4 yan3',
#   'english': 'suddenly',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d75')},
#  {'traditional': '一霎間',
#   'simplified': '一霎间',
#   'pinyin': 'yi1 sha4 jian1',
#   'english': 'in a flash',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d76')},
#  {'traditional': '一靈真性',
#   'simplified': '一灵真性',
#   'pinyin': 'yi1 ling2 zhen1 xing4',
#   'english': 'soul',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d77')},
#  {'traditional': '一面',
#   'simplified': '一面',
#   'pinyin': 'yi1 mian4',
#   'english': 'one side',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d78')},
#  {'traditional': '一面之交',
#   'simplified': '一面之交',
#   'pinyin': 'yi1 mian4 zhi1 jiao1',
#   'english': 'to have met once',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d79')},
#  {'traditional': '一面之詞',
#   'simplified': '一面之词',
#   'pinyin': 'yi1 mian4 zhi1 ci2',
#   'english': 'one side of the story',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d7a')},
#  {'traditional': '一面倒',
#   'simplified': '一面倒',
#   'pinyin': 'yi1 mian4 dao3',
#   'english': 'to be entirely on one side',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d7b')},
#  {'traditional': '一項一項地',
#   'simplified': '一项一项地',
#   'pinyin': 'yi1 xiang4 yi1 xiang4 de5',
#   'english': 'one by one',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d7c')},
#  {'traditional': '一頭',
#   'simplified': '一头',
#   'pinyin': 'yi1 tou2',
#   'english': 'one head',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d7d')},
#  {'traditional': '一頭栽進',
#   'simplified': '一头栽进',
#   'pinyin': 'yi1 tou2 zai1 jin4',
#   'english': 'to plunge into',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d7e')},
#  {'traditional': '一頭熱',
#   'simplified': '一头热',
#   'pinyin': 'yi1 tou2 re4',
#   'english': 'one-sided enthusiasm (abbr. for 剃頭挑子一頭熱|剃头挑子一头热[ti4 tou2 tiao1 zi5 yi1 tou2 re4])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d7f')},
#  {'traditional': '一頭霧水',
#   'simplified': '一头雾水',
#   'pinyin': 'yi1 tou2 wu4 shui3',
#   'english': 'to be confused',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d80')},
#  {'traditional': '一顆老鼠屎壞了一鍋湯',
#   'simplified': '一颗老鼠屎坏了一锅汤',
#   'pinyin': 'yi1 ke1 lao3 shu3 shi3 huai4 le5 yi1 guo1 tang1',
#   'english': 'lit. one pellet of rat feces spoiled the whole pot of soup (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d81')},
#  {'traditional': '一顆老鼠屎壞了一鍋粥',
#   'simplified': '一颗老鼠屎坏了一锅粥',
#   'pinyin': 'yi1 ke1 lao3 shu3 shi3 huai4 le5 yi1 guo1 zhou1',
#   'english': 'see 一粒老鼠屎壞了一鍋粥|一粒老鼠屎坏了一锅粥[yi1 li4 lao3 shu3 shi3 huai4 le5 yi1 guo1 zhou1]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d82')},
#  {'traditional': '一類',
#   'simplified': '一类',
#   'pinyin': 'yi1 lei4',
#   'english': 'same type',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d83')},
#  {'traditional': '一類保護動物',
#   'simplified': '一类保护动物',
#   'pinyin': 'yi1 lei4 bao3 hu4 dong4 wu4',
#   'english': 'class A protected animal',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d84')},
#  {'traditional': '一顰一笑',
#   'simplified': '一颦一笑',
#   'pinyin': 'yi1 pin2 yi1 xiao4',
#   'english': 'every frown and every smile',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d85')},
#  {'traditional': '一飲而盡',
#   'simplified': '一饮而尽',
#   'pinyin': 'yi1 yin3 er2 jin4',
#   'english': 'to drain the cup in one gulp (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d86')},
#  {'traditional': '一飽眼福',
#   'simplified': '一饱眼福',
#   'pinyin': 'yi1 bao3 yan3 fu2',
#   'english': "to feast one's eyes on (idiom)",
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d87')},
#  {'traditional': '一馬勺壞一鍋',
#   'simplified': '一马勺坏一锅',
#   'pinyin': 'yi1 ma3 shao2 huai4 yi1 guo1',
#   'english': 'one ladle (of sth bad) spoils the (whole) pot (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d88')},
#  {'traditional': '一馬平川',
#   'simplified': '一马平川',
#   'pinyin': 'yi1 ma3 ping2 chuan1',
#   'english': 'flat land one could gallop straight across (idiom); wide expanse of flat country',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d89')},
#  {'traditional': '一馬當先',
#   'simplified': '一马当先',
#   'pinyin': 'yi1 ma3 dang1 xian1',
#   'english': 'to take the lead',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d8a')},
#  {'traditional': '一騎絕塵',
#   'simplified': '一骑绝尘',
#   'pinyin': 'yi1 qi2 jue2 chen2',
#   'english': "(idiom) to lead the pack by a wide margin; to leave one's competitors trailing behind in one's dust",
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d8b')},
#  {'traditional': '一驚一乍',
#   'simplified': '一惊一乍',
#   'pinyin': 'yi1 jing1 yi1 zha4',
#   'english': 'frightened',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d8c')},
#  {'traditional': '一骨碌',
#   'simplified': '一骨碌',
#   'pinyin': 'yi1 gu1 lu5',
#   'english': 'with a rolling or twisting movement',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d8d')},
#  {'traditional': '一體',
#   'simplified': '一体',
#   'pinyin': 'yi1 ti3',
#   'english': 'an integral whole',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d8e')},
#  {'traditional': '一體兩面',
#   'simplified': '一体两面',
#   'pinyin': 'yi1 ti3 liang3 mian4',
#   'english': 'lit. one body two sides (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d8f')},
#  {'traditional': '一體化',
#   'simplified': '一体化',
#   'pinyin': 'yi1 ti3 hua4',
#   'english': 'integration',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d90')},
#  {'traditional': '一鬨而散',
#   'simplified': '一哄而散',
#   'pinyin': 'yi1 hong4 er2 san4',
#   'english': 'see 一哄而散[yi1 hong1 er2 san4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d91')},
#  {'traditional': '一鱗半爪',
#   'simplified': '一鳞半爪',
#   'pinyin': 'yi1 lin2 ban4 zhao3',
#   'english': 'lit. one scale and half a claw (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d92')},
#  {'traditional': '一鳴驚人',
#   'simplified': '一鸣惊人',
#   'pinyin': 'yi1 ming2 jing1 ren2',
#   'english': 'to amaze the world with a single brilliant feat (idiom); an overnight celebrity',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d93')},
#  {'traditional': '一黑早',
#   'simplified': '一黑早',
#   'pinyin': 'yi1 hei1 zao3',
#   'english': 'at dawn',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d94')},
#  {'traditional': '一點',
#   'simplified': '一点',
#   'pinyin': 'yi1 dian3',
#   'english': 'a bit',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d95')},
#  {'traditional': '一點一滴',
#   'simplified': '一点一滴',
#   'pinyin': 'yi1 dian3 yi1 di1',
#   'english': 'bit by bit',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d96')},
#  {'traditional': '一點一點',
#   'simplified': '一点一点',
#   'pinyin': 'yi1 dian3 yi1 dian3',
#   'english': 'little by little',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d97')},
#  {'traditional': '一點不',
#   'simplified': '一点不',
#   'pinyin': 'yi1 dian3 bu4',
#   'english': 'not at all',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d98')},
#  {'traditional': '一點兒',
#   'simplified': '一点儿',
#   'pinyin': 'yi1 dian3 r5',
#   'english': 'erhua variant of 一點|一点[yi1 dian3]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d99')},
#  {'traditional': '一點就通',
#   'simplified': '一点就通',
#   'pinyin': 'yi1 dian3 jiu4 tong1',
#   'english': 'a hint is all that is needed',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d9a')},
#  {'traditional': '一點水一個泡',
#   'simplified': '一点水一个泡',
#   'pinyin': 'yi1 dian3 shui3 yi1 ge4 pao4',
#   'english': 'honest and trustworthy (idiom)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d9b')},
#  {'traditional': '一點鄰域',
#   'simplified': '一点邻域',
#   'pinyin': 'yi1 dian3 lin2 yu4',
#   'english': '(math.) neighborhood of a point',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d9c')},
#  {'traditional': '一點點',
#   'simplified': '一点点',
#   'pinyin': 'yi1 dian3 dian3',
#   'english': 'a little bit',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d9d')},
#  {'traditional': '一黨',
#   'simplified': '一党',
#   'pinyin': 'yi1 dang3',
#   'english': 'one-party (state)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d9e')},
#  {'traditional': '一黨專制',
#   'simplified': '一党专制',
#   'pinyin': 'yi1 dang3 zhuan1 zhi4',
#   'english': 'one party dictatorship',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6d9f')},
#  {'traditional': '一鼓作氣',
#   'simplified': '一鼓作气',
#   'pinyin': 'yi1 gu3 zuo4 qi4',
#   'english': 'in a spurt of energy',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da0')},
#  {'traditional': '一鼻孔出氣',
#   'simplified': '一鼻孔出气',
#   'pinyin': 'yi1 bi2 kong3 chu1 qi4',
#   'english': 'lit. to breathe through the same nostril (idiom); fig. two people say exactly the same thing (usually derog.)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da1')},
#  {'traditional': '一齊',
#   'simplified': '一齐',
#   'pinyin': 'yi1 qi2',
#   'english': 'at the same time',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da2')},
#  {'traditional': '丁',
#   'simplified': '丁',
#   'pinyin': 'ding1',
#   'english': 'male adult',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da3')},
#  {'traditional': '丁丁',
#   'simplified': '丁丁',
#   'pinyin': 'Ding1 ding1',
#   'english': 'Tintin, cartoon character',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da4')},
#  {'traditional': '丁丁',
#   'simplified': '丁丁',
#   'pinyin': 'ding1 ding1',
#   'english': '(neologism) (slang) penis (丁丁 resembles "JJ", which is short for 雞雞|鸡鸡[ji1 ji1])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da5')},
#  {'traditional': '丁丁',
#   'simplified': '丁丁',
#   'pinyin': 'zheng1 zheng1',
#   'english': 'sound of chopping wood, chess pieces hitting the board etc',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da6')},
#  {'traditional': '丁丁炒麵',
#   'simplified': '丁丁炒面',
#   'pinyin': 'ding1 ding1 chao3 mian4',
#   'english': 'chopped fried noodles',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da7')},
#  {'traditional': '丁丑',
#   'simplified': '丁丑',
#   'pinyin': 'ding1 chou3',
#   'english': 'fourteenth year D2 of the 60 year cycle, e.g. 1997 or 2057',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da8')},
#  {'traditional': '丁二烯',
#   'simplified': '丁二烯',
#   'pinyin': 'ding1 er4 xi1',
#   'english': 'butadiene C4H6',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6da9')},
#  {'traditional': '丁二醇',
#   'simplified': '丁二醇',
#   'pinyin': 'ding1 er4 chun2',
#   'english': 'butyl glycol',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6daa')},
#  {'traditional': '丁亥',
#   'simplified': '丁亥',
#   'pinyin': 'ding1 hai4',
#   'english': 'twenty-fourth year D12 of the 60 year cycle, e.g. 2007 or 2067',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dab')},
#  {'traditional': '丁克',
#   'simplified': '丁克',
#   'pinyin': 'ding1 ke4',
#   'english': 'Dual Income, No Kids (DINK) (loanword)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dac')},
#  {'traditional': '丁內酯',
#   'simplified': '丁内酯',
#   'pinyin': 'ding1 nei4 zhi3',
#   'english': 'butyrolactone',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dad')},
#  {'traditional': '丁冬',
#   'simplified': '丁冬',
#   'pinyin': 'ding1 dong1',
#   'english': '(onom.) ding dong',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dae')},
#  {'traditional': '丁加奴',
#   'simplified': '丁加奴',
#   'pinyin': 'Ding1 jia1 nu2',
#   'english': 'Terengganu, northeast state of mainland Malaysia',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6daf')},
#  {'traditional': '丁卯',
#   'simplified': '丁卯',
#   'pinyin': 'ding1 mao3',
#   'english': 'fourth year D4 of the 60 year cycle, e.g. 1987 or 2047',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db0')},
#  {'traditional': '丁卯戰爭',
#   'simplified': '丁卯战争',
#   'pinyin': 'Ding1 mao3 Zhan4 zheng1',
#   'english': 'first Manchu invasion of Korea (1627)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db1')},
#  {'traditional': '丁卯胡亂',
#   'simplified': '丁卯胡乱',
#   'pinyin': 'Ding1 mao3 Hu2 luan4',
#   'english': 'first Manchu invasion of Korea (1627)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db2')},
#  {'traditional': '丁型肝炎',
#   'simplified': '丁型肝炎',
#   'pinyin': 'ding1 xing2 gan1 yan2',
#   'english': 'hepatitis D',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db3')},
#  {'traditional': '丁基',
#   'simplified': '丁基',
#   'pinyin': 'Ding1 Ji1',
#   'english': 'Ding Ji (1917-1944), real name Li Baicen 李百岑, journalist based in Yanan, martyr of the revolution',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db4')},
#  {'traditional': '丁基',
#   'simplified': '丁基',
#   'pinyin': 'ding1 ji1',
#   'english': 'butyl group (chemistry)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db5')},
#  {'traditional': '丁夫',
#   'simplified': '丁夫',
#   'pinyin': 'ding1 fu1',
#   'english': '(in ancient times) a man old enough for corvée or military service',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db6')},
#  {'traditional': '丁字',
#   'simplified': '丁字',
#   'pinyin': 'ding1 zi4',
#   'english': 'T-shaped',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db7')},
#  {'traditional': '丁字尺',
#   'simplified': '丁字尺',
#   'pinyin': 'ding1 zi4 chi3',
#   'english': 'T-square',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db8')},
#  {'traditional': '丁字梁',
#   'simplified': '丁字梁',
#   'pinyin': 'ding1 zi4 liang2',
#   'english': 'T-girder',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6db9')},
#  {'traditional': '丁字步',
#   'simplified': '丁字步',
#   'pinyin': 'ding1 zi4 bu4',
#   'english': 'T-step (basic dance position, with the feet forming a T shape)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dba')},
#  {'traditional': '丁字街',
#   'simplified': '丁字街',
#   'pinyin': 'ding1 zi4 jie1',
#   'english': 'T-junction',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dbb')},
#  {'traditional': '丁字褲',
#   'simplified': '丁字裤',
#   'pinyin': 'ding1 zi4 ku4',
#   'english': 'thong (underwear)',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dbc')},
#  {'traditional': '丁字鎬',
#   'simplified': '丁字镐',
#   'pinyin': 'ding1 zi4 gao3',
#   'english': 'hammer pick',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dbd')},
#  {'traditional': '丁客',
#   'simplified': '丁客',
#   'pinyin': 'ding1 ke4',
#   'english': 'see 丁克[ding1 ke4]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dbe')},
#  {'traditional': '丁寧',
#   'simplified': '丁宁',
#   'pinyin': 'ding1 ning2',
#   'english': 'variant of 叮嚀|叮咛[ding1 ning2]',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dbf')},
#  {'traditional': '丁寵家庭',
#   'simplified': '丁宠家庭',
#   'pinyin': 'ding1 chong3 jia1 ting2',
#   'english': 'double income family who have pets rather than children (see also 丁克[ding1 ke4])',
#   '_id': ObjectId('636b2b289cfbcb19c2fa6dc0')},
#  ...]

# %%
df_ce_dict =  pd.DataFrame(parsed_dict)
df_ce_dict.to_csv('../data/extracted/ce_dict.csv',index=False)

# %%
ceDictInsert = cedict.insert_many(parsed_dict)

# %%
for result in cedict.find({'simplified' : '工作'}):
    print(result)
# Out:
# {'_id': ObjectId('636b2b289cfbcb19c2faf3cd'), 'traditional': '工作', 'simplified': '工作', 'pinyin': 'gong1 zuo4', 'english': 'to work'}

# %%
result
# Out:
# {'_id': ObjectId('636b2b289cfbcb19c2faf3cd'),
#  'traditional': '工作',
#  'simplified': '工作',
#  'pinyin': 'gong1 zuo4',
#  'english': 'to work'}

# %%
cedict.find({"_id": ObjectId('636b2b289cfbcb19c2faf3cd')})

# %% [markdown]
# ### Chinese Character Radical Decomposition

# %%
# !pip install -q cchardet

# %%
import cchardet as chardet
import sys
import csv

def detect_encoding(filename):
    """Detect encoding and return decoded text, encoding, and confidence level."""
    filepath = Path(filename)

    # We must read as binary (bytes) because we don't yet know encoding
    blob = filepath.read_bytes()

    detection = chardet.detect(blob)
    encoding = detection["encoding"]
    confidence = detection["confidence"]
    text = blob.decode(encoding)
    
    print(f'Prediction: {encoding} with {confidence} percent confidence')

# %%
detect_encoding('../data/ChineseCharacterDecomposition.tsv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/jentlejames/Projects/Data/Chinese Automation/nb/database .ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/jentlejames/Projects/Data/Chinese%20Automation/nb/database%20.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> detect_encoding('../data/ccd.tsv')
#
# /home/jentlejames/Projects/Data/Chinese Automation/nb/database .ipynb Cell 17 in detect_encoding(filename)
#       <a href='vscode-notebook-cell:/home/jentlejames/Projects/Data/Chinese%20Automation/nb/database%20.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> filepath = Path(filename)
#       <a href='vscode-notebook-cell:/home/jentlejames/Projects/Data/Chinese%20Automation/nb/database%20.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> # We must read as binary (bytes) because we don't yet know encoding
# ---> <a href='vscode-notebook-cell:/home/jentlejames/Projects/Data/Chinese%20Automation/nb/database%20.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a> blob = filepath.read_bytes()
#      <a href='vscode-notebook-cell:/home/jentlejames/Projects/Data/Chinese%20Automation/nb/database%20.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a> detection = chardet.detect(blob)
#      <a href='vscode-notebook-cell:/home/jentlejames/Projects/Data/Chinese%20Automation/nb/database%20.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a> encoding = detection["encoding"]
#
# File ~/anaconda3/envs/ChineseAutomation/lib/python3.10/pathlib.py:1126, in Path.read_bytes(self)
#    1122 def read_bytes(self):
#    1123     """
#    1124     Open the file in bytes mode, read it, and close the file.
#    1125     """
# -> 1126     with self.open(mode='rb') as f:
#    1127         return f.read()
#
# File ~/anaconda3/envs/ChineseAutomation/lib/python3.10/pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/ccd.tsv'

# %%
charDecompTable = pd.read_csv('../data/ChineseCharacterDecomposition.tsv',header=0,sep='\t',encoding='utf-8')

# %%
charDecompTable
# Out:
#       Component  Strokes CompositionType LeftComponent  LeftStrokes  \
# 0             一        1               一             一            1
# 1             丁        2               吕             一            1
# 2             丂        2               一             丂            2
# 3             七        2               一             七            2
# 4             丄        2               一             丄            2
# ...         ...      ...             ...           ...          ...
# 21164         𨊠        9               吅             車            7
# 21165         𨊥        9               吕             車            7
# 21166         𨳐       11               回             門            8
# 21167         𨾴       14               咒             口            3
# 21168         𩰬       13               回             鬲           10
#
#       RightComponent  RightStrokes Signature Notes Section
# 0                  *             0         M     /       *
# 1                  亅             1        MN     /       一
# 2                  *             0       MVS     /       一
# 3                  *             0        JU     /       一
# 4                  *             0        LM     /       一
# ...              ...           ...       ...   ...     ...
# 21164              㔾             2       NaN     /       車
# 21165              凵             2       NaN     /       車
# 21166             女              3       NaN     /       門
# 21167              隹             8       NaN     /       隹
# 21168              㐄             3       NaN     /       鬲
#
# [21169 rows x 10 columns]
